# %%
import pandas as pd
import numpy as np

# %%
coffee_data = pd.read_csv("coffee_consumption.csv", encoding="latin")
coffee_data.head(20)
# Out:
#            Calendar years    1990    1991    1992    1993    1994    1995  \
# 0                     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1          European Union  34,230  37,663  38,240  40,292  36,850  38,735
# 2                 Austria   1,340   1,302   1,212   1,335   1,086   1,012
# 3                 Belgium     NaN     NaN     NaN     NaN     NaN     NaN
# 4      Belgium/Luxembourg   1,124     708     696     789     958   1,073
# 5                Bulgaria     102      17     175     327     353     393
# 6                 Croatia     NaN     NaN     135     132     164     288
# 7                  Cyprus      31      45      39      78      45      43
# 8          Czech Republic     659     525     472     448     509     511
# 9                 Denmark     865     909     959     891     908     758
# 10                Estonia     NaN     NaN      13      44      63      83
# 11                Finland   1,070     966   1,030   1,129   1,050     735
# ...

# %%
# Let's clear out some columns and rows
# Drop all teh NaN rows (blank or formatting rows in Excel)
coffee_data.drop([0, 31, 38, 40])
# Out:
#            Calendar years    1990    1991    1992    1993    1994    1995  \
# 1          European Union  34,230  37,663  38,240  40,292  36,850  38,735
# 2                 Austria   1,340   1,302   1,212   1,335   1,086   1,012
# 3                 Belgium     NaN     NaN     NaN     NaN     NaN     NaN
# 4      Belgium/Luxembourg   1,124     708     696     789     958   1,073
# 5                Bulgaria     102      17     175     327     353     393
# 6                 Croatia     NaN     NaN     135     132     164     288
# 7                  Cyprus      31      45      39      78      45      43
# 8          Czech Republic     659     525     472     448     509     511
# 9                 Denmark     865     909     959     891     908     758
# 10                Estonia     NaN     NaN      13      44      63      83
# 11                Finland   1,070     966   1,030   1,129   1,050     735
# 12                 France   5,205   5,557   5,614   5,507   5,111   5,313
# ...

# %%
# Let's get some GDP goodness. 
gdp_file = pd.read_csv("gdp_data.csv")
gdp_file.head()
# Out:
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME      Value Flag Codes
# 0      AUS  GDPHRWKD     TOT     USD         A  1970  26.793218        NaN
# 1      AUS  GDPHRWKD     TOT     USD         A  1971  27.462937        NaN
# 2      AUS  GDPHRWKD     TOT     USD         A  1972  28.067364        NaN
# 3      AUS  GDPHRWKD     TOT     USD         A  1973  28.645413        NaN
# 4      AUS  GDPHRWKD     TOT     USD         A  1974  28.189555        NaN

# %%
# Drop unneeded GDP info
gdp_data = gdp_file.drop(['INDICATOR', 'MEASURE', 'FREQUENCY', "Flag Codes"], axis=1)
gdp_data.head()
# Out:
#   LOCATION SUBJECT  TIME      Value
# 0      AUS     TOT  1970  26.793218
# 1      AUS     TOT  1971  27.462937
# 2      AUS     TOT  1972  28.067364
# 3      AUS     TOT  1973  28.645413
# 4      AUS     TOT  1974  28.189555

# %%
snapshot_gdp = gdp_data.head(20)
snapshot_gdp.to_csv("gdp_data_sample.csv")

# %%
snapshot_coffee = coffee_data.head(20)
snapshot_coffee.to_csv("coffee_data_sample.csv")
