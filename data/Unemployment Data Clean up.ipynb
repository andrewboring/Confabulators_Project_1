# %%
#Import libraries
import pandas as pd
import numpy as np

# %%
#Load the Health Data (Unemployment_data) CSV
health_data = pd.read_csv("Unemployment_data.csv")

health_data.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  \
# 0  % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 1  % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 2  Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 3  Adults (ages 15+) and children (0-14 years) li...        SH.HIV.TOTL
# 4  Adults (ages 15+) and children (ages 0-14) new...     SH.HIV.INCD.TL
#
#          1960        1961        1962        1963        1964        1965  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2  133.555013  134.159119  134.857912  134.504576  134.105211  133.569626
# ...

# %%
#Drop the Indicator Code Column
health_data_clean = health_data.drop(columns=['Indicator Code'], inplace = True)

# %%
#Move Each Year column to a single column
health_data_clean = pd.melt(health_data, id_vars=['Country Name', 'Country Code', 'Indicator Name'], var_name="Year", value_name="Value")
health_data_clean.head()
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name  Year       Value
# 0  % of females ages 15-49 having comprehensive c...  1960         NaN
# 1  % of males ages 15-49 having comprehensive cor...  1960         NaN
# 2  Adolescent fertility rate (births per 1,000 wo...  1960  133.555013
# 3  Adults (ages 15+) and children (0-14 years) li...  1960         NaN
# 4  Adults (ages 15+) and children (ages 0-14) new...  1960         NaN

# %%
#Filter only for the "Total Unemployment Row"
total_unemployment_data = health_data_clean.loc[health_data_clean['Indicator Name'] == 'Unemployment, total (% of total labor force)'] 

total_unemployment_data.head()
# Out:
#                         Country Name Country Code  \
# 333                       Arab World          ARB
# 678           Caribbean small states          CSS
# 1023  Central Europe and the Baltics          CEB
# 1368      Early-demographic dividend          EAR
# 1713             East Asia & Pacific          EAS
#
#                                     Indicator Name  Year  Value
# 333   Unemployment, total (% of total labor force)  1960    NaN
# 678   Unemployment, total (% of total labor force)  1960    NaN
# 1023  Unemployment, total (% of total labor force)  1960    NaN
# 1368  Unemployment, total (% of total labor force)  1960    NaN
# 1713  Unemployment, total (% of total labor force)  1960    NaN

# %%
#Write to csv
total_unemployment_data.to_csv('unemployment.csv',index=False)
